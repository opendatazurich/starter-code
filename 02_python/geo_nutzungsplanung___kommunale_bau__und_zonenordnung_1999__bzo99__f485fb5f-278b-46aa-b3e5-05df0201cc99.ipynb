# %% [markdown]
# ## Open Government Data, provided by **OpenDataZurich**
# *Autogenerated Python starter code for data set with identifier* **geo_nutzungsplanung___kommunale_bau__und_zonenordnung_1999__bzo99_**

# %% [markdown]
# ## Dataset
# # **Nutzungsplanung - kommunale Bau- und Zonenordnung 1999 (BZO99)**

# %% [markdown]
# ## Description
#
# Geodaten des Zonenplans und der Ergänzungspläne gemäss Art. 2 BauO.
# Es handelt sich um ein Extrakt des Geodatensatzes &quot;ÖREB-Kataster-STZH&quot; und wird stadtintern als &quot;Sekundärdatensatz ÖREB Nutzungsplaung&quot; bezeichnet.
#
# **Zweck**: Der Datensatz ist Teil der Bau- und Zonenordnung und somit gesetzlich vorgeschrieben.
#
# **Genereller Hinweis zum Geodatensatz:**
#
# Es handelt sich hierbei um einen Geodatensatz, welcher aus mehreren Geodatenelmenten besteht. Diese Geodatenelemente werden hier nicht im Detail beschrieben. Sie finden jedoch sämtliche Informationen - wie beispielsweise die Attributbeschreibungen - [«**Nutzungsplanung - kommunale Bau- und Zonenordnung 1999 (BZO99)»** auf Geocat.ch](https://www.geocat.ch/geonetwork/srv/ger/catalog.search#/metadata/90363d84-b1ff-401e-956a-9128a70672b3).
#
#
# **Datenerfassung:**
#
# Beteiligte Stellen: Amt für Städtebau, GeoZ
# Erfassungssystem: BZO-Fachschale, AV-System
#
# **Datengrundlage:**
#
# AV
#
# **Geodatenelemente:**
#
# Die vollständige Metadatenbeschreibung der Geodatenelemente finden Sie ebenfalls unter [«**Nutzungsplanung - kommunale Bau- und Zonenordnung 1999 (BZO99)»** auf Geocat.ch](https://www.geocat.ch/geonetwork/srv/ger/md.viewer#/full_view/90363d84-b1ff-401e-956a-9128a70672b3).
#
# ***BZO99_PROJ_REVISIONSGEBIET_V***:
#
# Gebiete in Revisions- oder Rekursverfahren (= projektierte Zonen oder Lärmempfindlichkeitsstufen)
#
#
# ***BZO99_ZONE_INNENL_F_V***:
#
# innenliegende Freihaltezone (informativ)
#
#
# ***BZO99_ZONE_ES_V***:
#
# Empfindlichkeitsstufen nach Art. 3 BauO
#
#
# ***BZO99_QUEZ_V***:
#
# Quartiererhaltungszonen
#
#
# ***BZO99_KERNZONE_V***:
#
# Kernzonen
#
#
# ***BZO99_HOCHHAUSGEBIET_V***:
#
# Hochhausgebiete nach Art. 9 BauO (Bestandteil der Sondernutzung)
#
#
# ***BZO99_GP_V***:
#
# Gestaltungspläne (Bestandteil der Sondernutzung)
#
#
# ***BZO99_SBV_V***:
#
# Sonderbauvorschriften (Bestandteil der Sondernutzung)
#
#
# ***BZO99_GP_PFLICHT_V***:
#
# Gebiete mit Gestaltungsplanpflicht nach Art. 4 BauO (Bestandteil der Sondernutzung)
#
#
# ***BZO99_PLANUNGSZONE_V***:
#
# Planungszonen (Bestandteil der Sondernutzung)
#
#
# ***BZO99_GEWAESSERABSTANDSL_V***:
#
# Gewässerabstandslinien
#
#
# ***BZO99_WALDABSTANDSL_V***:
#
# Waldabstandslinien
#
#
# ***BZO99_PROJ_GP_V***:
#
# Gestaltungspläne (projektiert) (Bestandteil der Sondernutzung)
#
#
# ***BZO99_PROJ_GEWAESSERABSTANDS_V***:
#
# Gewässerabstandslinien (projektiert)
#
#
# ***BZO99_PROJ_KERNZONE_V***:
#
# Kernzonen (projektiert)
#
#
# ***BZO99_PROJ_WALDABSTANDSL_V***:
#
# Waldabstandslinien (projektiert)
#
#
# ***BZO99_PROJ_ZONE_FFZ_V***:
#
# Gebiete mit Freiflächenziffer gemäss Art. 18 Abs. 2 BauO (projektiert)
#
#
# ***BZO99_ZONE_LAERMVORBELAST_V***:
#
# Lärmvorbelastetes Gebiet gemäss Art. 3 BauO
#
#
# ***BZO99_PROJ_ZONE_ES_V***:
#
# Empfindlichkeitsstufen nach Art. 3 BauO (projektiert)
#
#
# ***BZO99_PROJ_ZONE_LAERMVORBELA_V***:
#
# Lärmvorbelastetes Gebiet gemäss Art. 3 BauO (projektiert)
#
#
# ***BZO99_PROJ_ZONE_V***:
#
# Zonen (projektiert)
#
#
# ***BZO99_ZONE_V***:
#
# Zonen
#
#
# ***BZO99_ZONE_ERHOEHTE_AZ_V***:
#
# Gebiete mit erhöhter Ausnützung gemäss Art. 13 Abs. 2 BauO
#
#
# ***BZO99_PROJ_AUSSICHTSSCHUTZ_V***:
#
# Aussichtsschutz (projektiert) (Bestandteil der Sondernutzung)
#
#
# ***BZO99_PROJ_ZONE_WOHNANTEIL_V***:
#
# Wohnanteilsgrenze (projektiert)
#
#
# ***BZO99_PROJ_GP_PFLICHT_V***:
#
# Gebiete mit Gestaltungsplanpflicht nach Art. 4 BauO (projektiert) (Bestandteil der Sondernutzung)
#
#
# ***BZO99_PROJ_HOCHHAUSGEBIET_V***:
#
# Hochhausgebiete nach Art. 9 BauO (projektiert) (Bestandteil der Sondernutzung)
#
#
# ***BZO99_PROJ_PLANUNGSZONE_V***:
#
# Planungszonen (projektiert) (Bestandteil der Sondernutzung)
#
#
# ***BZO99_PROJ_SBV_V***:
#
# Sonderbauvorschriften (projektiert) (Bestandteil der Sondernutzung)
#
#
# ***BZO99_PROJ_ZONE_ERHOEHTE_AZ_V***:
#
# Gebiete mit erhöhter Ausnützung gemäss Art. 13 Abs. 2 BauO (projektiert)
#
#
# ***BZO99_ZONE_WOHNANTEIL_V***:
#
# Wohnanteilsgrenze
#
#
# ***BZO99_AUSSICHTSSCHUTZ_V***:
#
# Aussichtsschutz (Bestandteil der Sondernutzung)
#
#
# ***BZO99_PROJ_QUEZ_V***:
#
# Quartiererhaltungszonen (projektiert)
#
#
# ***BZO99_PROJ_ZONE_INNENL_F_V***:
#
# innenliegende Freihaltezone (projektiert) (informativ)
#
#
# ***BZO99_ZONE_FFZ_V***:
#
# Gebiete mit Freiflächenziffer gemäss Art. 18 Abs. 2 BauO
#
#
#
#
# **Statisches Vorschaubild:**
#
# ![BildText](https://www.gis.stadt-zuerich.ch/zueriplan_docs/geocat/90363d84-b1ff-401e-956a-9128a70672b3.png)

# %% [markdown]
# ## Data set links
#
# [Direct link by OpenDataZurich for dataset](https://data.stadt-zuerich.ch/dataset/geo_nutzungsplanung___kommunale_bau__und_zonenordnung_1999__bzo99_)
#
# https://www.stadt-zuerich.ch/geodaten/download/Nutzungsplanung___kommunale_Bau__und_Zonenordnung_1999__BZO99_?format=geojson_link<br>

# %% [markdown]
# ## Metadata
# - **Publisher** `Raumentwicklung & Architektur, Amt für Städtebau, Hochbaudepartement`
# - **Maintainer** `Open Data Zürich`
# - **Maintainer_email** `opendata@zuerich.ch`
# - **Keywords** `Basis­karten,Bauen und Wohnen,Umwelt,Ver­walt­ung`
# - **Tags** `['abstandslinien', 'bauordnung', 'bzo', 'erganzungsplane', 'geodaten', 'geoportal', 'liniendaten', 'nutzungsplanung', 'polygondaten', 'stzh', 'vektordaten', 'zonenplan']`
# - **Metadata_created** `2023-11-06T03:14:40.724782`
# - **Metadata_modified** `2025-08-23T06:35:38.031417`

# %% [markdown]
# ## Imports and helper functions

# %%
import matplotlib.pyplot as plt
import pandas as pd 

import json
import xml.etree.ElementTree as ET
import requests
import geopandas as gpd
import re

# %%
# helper function for reading datasets with proper separator
def get_dataset(url):
    # get URL ofs WFS service
    dataset_identifier = re.search(r'\/([^\/\?]+)\?', url).group(1)
    url_geoportal = f"https://www.ogd.stadt-zuerich.ch/wfs/geoportal/{dataset_identifier}"
    print("Getting available layers from:", url_geoportal)
    
    # Parameter for GetCapabilities
    params = {
        "service": "WFS",
        "version": "1.1.0",
        "request": "GetCapabilities"
    }
    
    # send GetCapabilities
    response = requests.get(url_geoportal, params=params)

    # parse XML answer
    root = ET.fromstring(response.content)

    # define Namespace 
    namespace = {'wfs': 'http://www.opengis.net/wfs'}
    
    # Exctract available layers
    layers = [feature_type.find('wfs:Name', namespace).text for feature_type in root.findall('.//wfs:FeatureType', namespace)]
    
    print("Available layers:", layers)
    print("First layer is set as default. To chose another layer set it as typename in the get_dataset() function.")

    # set first layer als typename
    typename = layers[0]
    print("Chosen typename:", typename)

    # Parameter GetFeature request
    params = {
        "service": "WFS",
        "version": "1.1.0",
        "request": "GetFeature",
        "typename": typename,
        "outputFormat": "application/json"
    }
    
    # GetFeature request
    response = requests.get(url_geoportal, params=params)

    # Load GeoJSON in GeoDataFrame
    gdf = gpd.read_file(json.dumps(response.json()))
    return gdf

# %% [markdown]
# ## Load the data

# %%
gdf = get_dataset('https://www.stadt-zuerich.ch/geodaten/download/Nutzungsplanung___kommunale_Bau__und_Zonenordnung_1999__BZO99_?format=geojson_link')

# %% [markdown]
# ## Analyze the data

# %%
gdf.plot()

# %%
# drop columns that have no values
gdf.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {gdf.shape[0]:,.0f} rows (observations) and {gdf.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {gdf.duplicated().sum()} exact duplicates in the data.')

# %%
gdf.info(memory_usage='deep', verbose=True)

# %%
gdf.head()

# %%
# display a small random sample transposed in order to see all variables
gdf.sample(3).T

# %%
# describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(gdf.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(gdf.describe(include='number'))
except:
    print("No numercial data in dataset.")

# %%
# plot a histogram for each numerical feature
try:
    gdf.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numercial data to plot.")

# %%
# continue your code here...

# %% [markdown]
# **Contact**: opendata@zuerich.ch
